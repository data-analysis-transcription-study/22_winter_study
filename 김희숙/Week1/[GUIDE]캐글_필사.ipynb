# %% [markdown]
# [[GUIDE, KOR, DG] 데이터 분석 어떻게 시작해야 하나요?](https://www.kaggle.com/daehungwak/guide-kor-dg)

# %% [markdown]
# 1. 데이터 분석 시작하기 앞서서
# 2. 데이터 셋 확인
# 3. 탐색적 데이터 분석 (EDA, Exploratory Data Analysis)
# 4. 특성 공학 (Feature Engineering)
# 5. 모델 개발 및 학습
#   - scikit-learn을 사용한 RandomForest모델 개발
#   - keras를 사용한 NN 모델 개발 (미완)
# 6. 모델 예측 및 평가
#   - RandomForest 예측 및 평가
#   - NN 예측 및 평가 (미완)
# 7. 결론
# 8. 어떻게 공부하는게 좋을까요?

# %% [markdown]
# # 1. 데이터 셋 확인

# %%
# import module
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
import sklearn

plt.style.use('seaborn')
sns.set(font_scale=2.5)

import missingno as msno

#ignore warnings
import warnings
warnings.filterwarnings('ignore') # 워닝 메세지 생략

# %matplotlib inline

# %%
# 구글 드라이브 연동
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.listdir("/content/drive/My Drive/Colab Notebooks/data/")
# Out:
# ['eng-fra.txt',
#  'freeformResponses.csv',
#  'names',
#  'test.mp4',
#  'test.wav',
#  'asr-install.sh',
#  'house_tiny.csv',
#  'schema.csv',
#  'multipleChoiceResponses.csv',
#  'conversionRates.csv',
#  'train.csv',
#  'test.csv',
#  'sampleSubmission.csv',
#  'Score_0.33092_submission.csv',
#  'sample_submission.csv',
#  'test_kaggle.csv',
#  'train-kaggle.csv']

# %%
df_train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/train-kaggle.csv')
df_test = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/test_kaggle.csv')
df_submit = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/sample_submission.csv')

# %%
df_train.shape, df_test.shape, df_submit.shape
# Out:
# ((891, 12), (418, 11), (418, 2))

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_submit.columns
# Out:
# Index(['PassengerId', 'Survived'], dtype='object')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_test.head()
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %%
df_submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %% [markdown]
# 타이타닉 데이터 Feature
# - survival - 생존유무, target 값. (0 = 사망, 1 = 생존)
# - pclass - 티켓 클래스. (1 = 1st, 2 = 2nd, 3 = 3rd)
# - sex - 성별
# - Age - 나이(세)
# - sibsp - 함께 탑승한 형제자매, 배우자 수 총합
# - parch - 함께 탑승한 부모, 자녀 수 총합
# - ticket - 티켓 넘버
# - fare - 탑승 요금
# - cabin - 객실 넘버
# - bembarked - 탑승 항구

# %%
df_train.dtypes # feature types
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df_train.describe() # feature 기초 통계량
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ### 1.1 결측치(Null Data) 확인

# %%
df_train.isnull().sum() / df_train.shape[0]
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.198653
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Cabin          0.771044
# Embarked       0.002245
# dtype: float64

# %%
df_train.isnull().sum(), df_train.shape[0]
# Out:
# (PassengerId      0
#  Survived         0
#  Pclass           0
#  Name             0
#  Sex              0
#  Age            177
#  SibSp            0
#  Parch            0
#  Ticket           0
#  Fare             0
#  Cabin          687
#  Embarked         2
#  dtype: int64, 891)

# %%
df_test.isnull().sum() / df_test.shape[0]
# Out:
# PassengerId    0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.205742
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.002392
# Cabin          0.782297
# Embarked       0.000000
# dtype: float64

# %%
df_test.isnull().sum(), df_test.shape[0]
# Out:
# (PassengerId      0
#  Pclass           0
#  Name             0
#  Sex              0
#  Age             86
#  SibSp            0
#  Parch            0
#  Ticket           0
#  Fare             1
#  Cabin          327
#  Embarked         0
#  dtype: int64, 418)

# %% [markdown]
# ### 1.2 Target Label, Survived 확인

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot - Survived')

plt.show()

# %% [markdown]
# # 2. 탐색적 데이터 분석 (EDA, Exploratory Data Analysis

# %% [markdown]
# ### 2.1 Pcalss

# %%
# pcalss 그룹 별 데이터 카운트
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
# pclass 그룹 별 생존자 수 합
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
# 위와 같은 작업을 crosstab으로 편하게 진행
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
# mean은 생존률
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
# 생존률 시각화
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().plot.bar()

# %% [markdown]
# ### 2.2 Sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')

plt.show()

# %% [markdown]
# ### 2.3 Both Sex and Pclass

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %% [markdown]
# ### 2.4 Age

# %%
print('제일 나이 많은 탑승객 : {:.1f} Years'.format(df_train['Age'].max()))
print('제일 어린 탑승객 : {:.1f} Years'.format(df_train['Age'].min()))
print('탑승객 평균 나이 : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객 : 80.0 Years
# 제일 어린 탑승객 : 0.4 Years
# 탑승객 평균 나이 : 29.7 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9,5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])

plt.show()

# %%
# 클래스별 나이 분포
plt.figure(figsize=(8,6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %%
# 나이대 별 생존 확률
cummulate_survival_ratio = []

for i in range(1,80):
    cummulate_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))

plt.figure(figsize=(7,7))
plt.plot(cummulate_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0~x)')
plt.show()

# %% [markdown]
# ### 2.5 Embarked

# %%
df_train['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
f, ax = plt.subplots(1, 1, figsize=(7,7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

# %%
# 다른 feature들과 탑승구(Embarked) 관계
f, ax = plt.subplots(2,2, figsize=(20,15))
# Embarked 분포
sns.countplot('Embarked', data=df_train, ax=ax[0,0])
ax[0,0].set_title('(1) No. Of Passengers Boarded')
# Embarked 와 성별
sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0,1])
ax[0,1].set_title('(2) Male-Female Split for Embarked')
# Embarked 와 생존
sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1,0])
ax[1,0].set_title('(3) Embarked vs Survived')
# Embarked 와 클래스 의자
sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1,1])
ax[1,1].set_title('(4) Embarked vs Pclass')
plt.subplots_adjust(wspace=0.2, hspace=0.5)

plt.show()

# %% [markdown]
# ### 2.6 Family - SibSp(형제 자매) + Parch(부모, 자녀)

# %%
df_train['SibSp'].head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# Name: SibSp, dtype: int64

# %%
df_train['Parch'].head() # parch - 함께 탑승한 부모, 자녀 수 총합
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Parch, dtype: int64

# %%
# 가족 = SibSp + Parch
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1 # 자신을 포함해야하니 1을 더해야 함
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1

# %%
print("Maximum size of Family: ", df_train['FamilySize'].max())
print("Minimum size of Family: ", df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %%
f,ax=plt.subplots(1, 3, figsize=(40,10))
sns.countplot('FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passengers Boarded', y=1.02)

sns.countplot('FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize',  y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize',  y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# ### 2.7 Fare

# %%
# 요금(Fare) 비대칭도 확인
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %%
# test data의 fare null값을 평균으로 채움
df_test.loc[df_test.Fare.isnull(), 'Fare'] = df_test['Fare'].mean() 

df_train['Fare'] = df_train['Fare'].map(lambda i : np.log(i) if i > 0 else 0) #로그변환
df_test['Fare'] = df_test['Fare'].map(lambda i : np.log(i) if i > 0 else 0)

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness : {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
g = g.legend(loc='best')

# %% [markdown]
# ### 2.8 Cabin

# %%
# Cabin 피쳐의 null 비율 계산
df_train['Cabin'].isnull().sum() / df_train.shape[0]
# Out:
# 0.7710437710437711

# %%
df_train.head()[['PassengerId', 'Cabin']]
# Out:
#    PassengerId Cabin
# 0            1   NaN
# 1            2   C85
# 2            3   NaN
# 3            4  C123
# 4            5   NaN

# %% [markdown]
# ### 2.9 Ticket¶

# %%
df_train['Ticket'].value_counts()
# Out:
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: Ticket, Length: 681, dtype: int64

# %% [markdown]
# 굉장히 다양한 티켓 넘버에서 어떤 특징을 이끌어내서 생존과 연결시킬 수 있는지 띵킹해보기

# %% [markdown]
# # 3. 특성 공학 (Feature Engineering)

# %% [markdown]
# * train 뿐만 아니라 test 도 똑같이 적용

# %% [markdown]
# ### 3.1 Fill Null

# %%
# 3.1.1 Fill Null in Age using title
df_train['Age'].isnull().sum()
# Out:
# 177

# %%
# 이름에서 title 추출
df_train['Initial']= df_train.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations
df_test['Initial']= df_test.Name.str.extract('([A-Za-z]+)\.') #lets extract the Salutations

# %%
# Initial 과 Sex 간의 count 
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r') #Checking the Initials with the Sex
# Out:
# <style type="text/css">
# #T_0b3cf_row0_col0, #T_0b3cf_row0_col1, #T_0b3cf_row0_col3, #T_0b3cf_row0_col4, #T_0b3cf_row0_col5, #T_0b3cf_row0_col7, #T_0b3cf_row0_col8, #T_0b3cf_row0_col12, #T_0b3cf_row0_col15, #T_0b3cf_row0_col16, #T_0b3cf_row1_col2, #T_0b3cf_row1_col6, #T_0b3cf_row1_col9, #T_0b3cf_row1_col10, #T_0b3cf_row1_col11, #T_0b3cf_row1_col13, #T_0b3cf_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_0b3cf_row0_col2, #T_0b3cf_row0_col6, #T_0b3cf_row0_col9, #T_0b3cf_row0_col10, #T_0b3cf_row0_col11, #T_0b3cf_row0_col13, #T_0b3cf_row0_col14, #T_0b3cf_row1_col0, #T_0b3cf_row1_col1, #T_0b3cf_row1_col3, #T_0b3cf_row1_col4, #T_0b3cf_row1_col5, #T_0b3cf_row1_col7, #T_0b3cf_row1_col8, #T_0b3cf_row1_col12, #T_0b3cf_row1_col15, #T_0b3cf_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0b3cf_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
# Initial 정리
df_train['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

df_test['Initial'].replace(['Mlle','Mme','Ms','Dr','Major','Lady','Countess','Jonkheer','Col','Rev','Capt','Sir','Don', 'Dona'],
                        ['Miss','Miss','Miss','Mr','Mr','Mrs','Mrs','Other','Other','Other','Mr','Mr','Mr', 'Mr'],inplace=True)

# %%
# Initial 들이 가지는 평균값들
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass  ...     Parch      Fare  FamilySize
# Initial                                   ...
# Master    414.975000  0.575000  2.625000  ...  1.375000  3.340710    4.675000
# Miss      411.741935  0.704301  2.284946  ...  0.537634  3.123713    2.236559
# Mr        455.880907  0.162571  2.381853  ...  0.151229  2.651507    1.444234
# Mrs       456.393701  0.795276  1.984252  ...  0.818898  3.443751    2.511811
# Other     564.444444  0.111111  1.666667  ...  0.111111  2.641605    1.222222
#
# [5 rows x 8 columns]

# %%
# Initial 별 생존
df_train.groupby('Initial')['Survived'].mean().plot.bar()

# %%
# statistics 을 이용하여 결측치 처리
# train data에서 얻은 statistics를 기반으로 test 의 null data를 채워야함 (?)
df_train.groupby('Initial').mean()
# Out:
#          PassengerId  Survived    Pclass  ...     Parch      Fare  FamilySize
# Initial                                   ...
# Master    414.975000  0.575000  2.625000  ...  1.375000  3.340710    4.675000
# Miss      411.741935  0.704301  2.284946  ...  0.537634  3.123713    2.236559
# Mr        455.880907  0.162571  2.381853  ...  0.151229  2.651507    1.444234
# Mrs       456.393701  0.795276  1.984252  ...  0.818898  3.443751    2.511811
# Other     564.444444  0.111111  1.666667  ...  0.111111  2.641605    1.222222
#
# [5 rows x 8 columns]

# %%
# initial 그룹별 Age 평균 값 계산 넣기
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mr'),'Age'] = 33
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Mrs'),'Age'] = 36
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Master'),'Age'] = 5
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Miss'),'Age'] = 22
df_train.loc[(df_train.Age.isnull())&(df_train.Initial=='Other'),'Age'] = 46

df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mr'),'Age'] = 33 # test에 train의 평균 넣음
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Mrs'),'Age'] = 36
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Master'),'Age'] = 5
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Miss'),'Age'] = 22
df_test.loc[(df_test.Age.isnull())&(df_test.Initial=='Other'),'Age'] = 46

# %%
df_train.isnull().sum()[df_train.isnull().sum() > 0] # null 체크
# Out:
# Cabin       687
# Embarked      2
# dtype: int64

# %%
df_test.isnull().sum()[df_test.isnull().sum() > 0]
# Out:
# Cabin    327
# dtype: int64

# %% [markdown]
# [Null 처리하는 다른 방법](https://www.kaggle.com/yassineghouzam/titanic-top-4-with-ensemble-modeling)

# %%
# 3.1.2 Fill Null in Embarked
print('Embarked has ', sum(df_train['Embarked'].isnull()), ' Null values')
# Out:
# Embarked has  2  Null values

# %%
# 간단하게 채우기
df_train['Embarked'].fillna('S', inplace=True)

# %%
df_train.isnull().sum()[df_train.isnull().sum() > 0]
# Out:
# Cabin    687
# dtype: int64

# %% [markdown]
# ### 3.2. Change Age(continuous to categorical)

# %%
# continuous 를 categorical 로 바꾸면 information loss 가능성 있음
def category_age(x):
    if x < 10:
        return 0 # ~9 
    elif x < 20: 
        return 1 # 10~19 #10대
    elif x < 30:
        return 2 # 20대
    elif x < 40:
        return 3 # 30대
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7    
    
df_train['Age_cat'] = df_train['Age'].apply(category_age)
df_test['Age_cat'] = df_test['Age'].apply(category_age)

# %%
df_train.groupby(['Age_cat'])['PassengerId'].count()
# Out:
# Age_cat
# 0     66
# 1    102
# 2    256
# 3    304
# 4     89
# 5     48
# 6     19
# 7      7
# Name: PassengerId, dtype: int64

# %% [markdown]
# - 보통 파생 피쳐 만든 후 원 컬럼을 제거

# %% [markdown]
# ### 3.3 Change Initial, Embarked and Sex (string to numerical)

# %%
# Initial 수치화
df_train['Initial'] = df_train['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})
df_test['Initial'] = df_test['Initial'].map({'Master': 0, 'Miss': 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})

# %%
# Embarked 수치화
df_train['Embarked'] = df_train['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
df_test['Embarked'] = df_test['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
# check
df_train['Embarked'].isnull().any() , df_train['Embarked'].dtypes
# Out:
# (False, dtype('int64'))

# %%
# Sex 수치화
df_train['Sex'] = df_train['Sex'].map({'female': 0, 'male': 1})
df_test['Sex'] = df_test['Sex'].map({'female': 0, 'male': 1})

# %%
# 각 feature 간의 상관관계 # 히트맵 이용
heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat', 'Age']] 

colormap = plt.cm.RdBu # 컬러지정
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='white', annot=True, annot_kws={"size": 16}) # corr() 필수

del heatmap_data # 만들고 나서 데이터 삭제

# %% [markdown]
# ### 3.4 One-hot encoding on Initial and Embarked¶

# %% [markdown]
# - 각 클래스간 연관성을 Orthogonal(직교, 동일하게) 만들 수 있음
# - 수치화 했을 때의 문제 해결 방안

# %%
# get_dummies 이용
df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initial')
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked_0  Embarked_1  Embarked_2
# 0            1         0       3  ...          0           0           1
# 1            2         1       1  ...          1           0           0
# 2            3         1       3  ...          0           0           1
# 3            4         1       1  ...          0           0           1
# 4            5         0       3  ...          0           0           1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### 3.5 Drop columns

# %%
# 필요없는 피쳐 제거
df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True) #  axis=1 열 드랍
df_test.drop(['PassengerId', 'Name',  'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex   Age  ...  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0         0       3    1  22.0  ...          0           0           0           1
# 1         1       1    0  38.0  ...          0           1           0           0
# 2         1       3    0  26.0  ...          0           0           0           1
# 3         1       1    0  35.0  ...          0           0           0           1
# 4         0       3    1  35.0  ...          0           0           0           1
#
# [5 rows x 15 columns]

# %%
df_train.dtypes
# Out:
# Survived        int64
# Pclass          int64
# Sex             int64
# Age           float64
# Fare          float64
# FamilySize      int64
# Age_cat         int64
# Initial_0       uint8
# Initial_1       uint8
# Initial_2       uint8
# Initial_3       uint8
# Initial_4       uint8
# Embarked_0      uint8
# Embarked_1      uint8
# Embarked_2      uint8
# dtype: object

# %%
df_test.head()
# Out:
#    Pclass  Sex   Age      Fare  ...  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0       3    1  34.5  2.057860  ...          0           0           1           0
# 1       3    0  47.0  1.945910  ...          0           0           0           1
# 2       2    1  62.0  2.270836  ...          0           0           1           0
# 3       3    1  27.0  2.159003  ...          0           0           0           1
# 4       3    0  22.0  2.508582  ...          0           0           0           1
#
# [5 rows x 14 columns]

# %%
df_test.dtypes
# Out:
# Pclass          int64
# Sex             int64
# Age           float64
# Fare          float64
# FamilySize      int64
# Age_cat         int64
# Initial_0       uint8
# Initial_1       uint8
# Initial_2       uint8
# Initial_3       uint8
# Initial_4       uint8
# Embarked_0      uint8
# Embarked_1      uint8
# Embarked_2      uint8
# dtype: object

# %% [markdown]
# # 4. 모델 개발 및 학습

# %% [markdown]
# -  타이타닉 문제: target class(survived)가 있으며, target class 는 0, 1로 이루어져 있으므로(binary) binary classfication 문제

# %%
#importing all the required ML packages
from sklearn.ensemble import RandomForestClassifier 
from sklearn import metrics # 모델 평가
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 4.1 Preparation - Split dataset into train, valid(dev), test set

# %%
# 학습과 테스트 데이터 분리
X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_train.shape, X_test.shape
# Out:
# ((891, 14), (418, 14))

# %%
#  valid(dev) set을 따로 만들어 모델 평가
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.2, random_state=2018)

# %%
y_tr.shape, y_vld.shape
# Out:
# ((712,), (179,))

# %% [markdown]
# ### 4.2 Model generation and prediction

# %%
# 랜덤포레스트
model_rf = RandomForestClassifier()
model_rf.fit(X_tr, y_tr)
prediction = model_rf.predict(X_vld)

# %%
print('총 {}명 중 {:.2f}% 정확도로 생존을 맞춤'.format(y_vld.shape[0], 100 * metrics.accuracy_score(prediction, y_vld)))
# Out:
# 총 179명 중 79.89% 정확도로 생존을 맞춤

# %%
# feature importances
from pandas import Series

feature_importance = model_rf.feature_importances_
Series_feat_imp = Series(feature_importance, index=df_test.columns)

plt.figure(figsize=(8, 8))
Series_feat_imp.sort_values(ascending=True).plot.barh()
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# # 4.B keras를 사용한 NN 모델 개발

# %%
pip install Adam

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
#from keras.optimizers import Adam, SGD 
# ImportError: cannot import name 'Adam' from 'keras.optimizers' (/usr/local/lib/python3.7/dist-packages/keras/optimizers.py)

from tensorflow.keras.optimizers import Adam

# %%
# 딥러닝
nn_model = Sequential()
nn_model.add(Dense(32,activation='relu',input_shape=(14,)))
nn_model.add(Dropout(0.2))
nn_model.add(Dense(64,activation='relu'))
nn_model.add(Dropout(0.2))
nn_model.add(Dense(32,activation='relu'))
nn_model.add(Dropout(0.2))
nn_model.add(Dense(1,activation='sigmoid'))

Loss = 'binary_crossentropy'
nn_model.compile(loss=Loss,optimizer=Adam(),metrics=['accuracy'])
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 32)                480
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_1 (Dense)             (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 1)                 33
#
# ...
# Total params: 4,705
# Trainable params: 4,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = nn_model.fit(X_tr,y_tr,
                    batch_size=64,
                    epochs=500,
                    validation_data=(X_vld, y_vld),
                    verbose=1)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 2s 23ms/step - loss: 0.8853 - accuracy: 0.5449 - val_loss: 0.6627 - val_accuracy: 0.6425
# Epoch 2/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8147 - accuracy: 0.5618 - val_loss: 0.6663 - val_accuracy: 0.6425
# Epoch 3/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.7456 - accuracy: 0.5646 - val_loss: 0.6573 - val_accuracy: 0.6480
# Epoch 4/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7148 - accuracy: 0.6096 - val_loss: 0.6313 - val_accuracy: 0.6536
# Epoch 5/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7036 - accuracy: 0.5927 - val_loss: 0.6430 - val_accuracy: 0.6536
# Epoch 6/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6906 - accuracy: 0.5885 - val_loss: 0.6468 - val_accuracy: 0.6872
# Epoch 7/500
# ...

# %%
history

# %%
# history 시각화
hists = [history]
hist_df = pd.concat([pd.DataFrame(hist.history) for hist in hists], sort=True)
hist_df.index = np.arange(1, len(hist_df)+1)

fig, axs = plt.subplots(nrows=2, sharex=True, figsize=(16, 10))
axs[0].plot(hist_df.val_accuracy, lw=5, label='Validation Accuracy')
axs[0].plot(hist_df.accuracy, lw=5, label='Training Accuracy')
axs[0].set_ylabel('Accuracy')
axs[0].set_xlabel('Epoch')
axs[0].grid()
axs[0].legend(loc=0)
axs[1].plot(hist_df.val_loss, lw=5, label='Validation MLogLoss')
axs[1].plot(hist_df.loss, lw=5, label='Training MLogLoss')
axs[1].set_ylabel('MLogLoss')
axs[1].set_xlabel('Epoch')
axs[1].grid()
axs[1].legend(loc=0)
# fig.savefig('hist.png', dpi=300)

plt.show()

# %% [markdown]
# # 5. 모델 예측 및 평가

# %%
df_submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
prediction = model_rf.predict(X_test)
df_submit['Survived'] = prediction

# %%
df_submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         1
# 4          896         1

# %%
# df_submit.to_csv('my_first_submission.csv', index=False)

# %% [markdown]
# # 5.B NN 예측 및 평가

# %%
submission2 = pd.read_csv('/content/drive/My Drive/Colab Notebooks/data/sample_submission.csv')
prediction = nn_model.predict(X_test)
prediction = prediction > 0.5
prediction = prediction.astype(np.int)
prediction = prediction.T[0]
prediction.shape
# Out:
# (418,)

# %%
submission2['Survived'] = prediction
# submission2.to_csv('my_nn_submission.csv', index=False)

# %%
submission2.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1
